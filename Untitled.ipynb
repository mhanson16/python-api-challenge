# %%
# !pip install GeoViews
# !pip install cartopy
# Out:
# ...
#   Using cached geoviews-1.9.6-py2.py3-none-any.whl (508 kB)
# ...

# %%
conda install -c conda-forge cartopy
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/MaddyHanson/opt/anaconda3
#
#   added / updated specs:
#     - cartopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cartopy-0.21.1             |   py39hfb1ba4b_1         1.5 MB  conda-forge
#     geos-3.11.2                |       hf0c8a7f_0         1.2 MB  conda-forge
#     proj-9.0.1                 |       h05f0992_1         2.8 MB  conda-forge
#     pyproj-3.3.1               |   py39h94c78e7_1         455 KB  conda-forge
#     pyshp-2.3.1                |     pyhd8ed1ab_0         941 KB  conda-forge
#     shapely-2.0.1              |   py39h1518777_1         388 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.3 MB
#
# The following NEW packages will be INSTALLED:
#
# ...
