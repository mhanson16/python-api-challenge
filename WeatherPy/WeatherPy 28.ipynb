# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
# this does not work for me, setting as variable instead
# from api_keys.py import weather_api_key
weather_api_key = "8e28b154ab0a7096657a3124177ac015"

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 595

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

# from api doc
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print(f"Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({'City': city.title(), 
                          'Lat': city_lat, 
                          'Lng': city_lng, 
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Date': city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ballymena
# Processing Record 2 of Set 1 | marzuq
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | sola
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | almaznyy
# Processing Record 9 of Set 1 | yar-sale
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | beringovskiy
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | urumqi
# Processing Record 15 of Set 1 | saint anthony
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | lompoc
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | cockburn town
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | kristianstad
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | dahuk
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | vardo
# Processing Record 29 of Set 1 | khandbari
# Processing Record 30 of Set 1 | pa sang
# Processing Record 31 of Set 1 | aklavik
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | isangel
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | ternate
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | silikatnyy
# Processing Record 41 of Set 1 | miri
# Processing Record 42 of Set 1 | northam
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | asha
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | touros
# Processing Record 47 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | palmer
# Processing Record 50 of Set 1 | hambantota
# Processing Record 1 of Set 2 | saryg-sep
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | adjumani
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | rognedino
# Processing Record 7 of Set 2 | tottori
# Processing Record 8 of Set 2 | salalah
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | beloha
# Processing Record 11 of Set 2 | cabo san lucas
# Processing Record 12 of Set 2 | camocim
# Processing Record 13 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | flinders
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | aksarka
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | okoneshnikovo
# Processing Record 25 of Set 2 | tateyama
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | chandbali
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | caborca
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | yeppoon
# Processing Record 33 of Set 2 | lata
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | antofagasta
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | korla
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | olinda
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | brosteni
# Processing Record 48 of Set 2 | fairbanks
# Processing Record 49 of Set 2 | mission bend
# Processing Record 50 of Set 2 | maldonado
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | beboto
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | veraval
# Processing Record 8 of Set 3 | petrovsk
# Processing Record 9 of Set 3 | hasaki
# Processing Record 10 of Set 3 | namibe
# Processing Record 11 of Set 3 | kitimat
# Processing Record 12 of Set 3 | soverato
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | prachuap khiri khan
# Processing Record 15 of Set 3 | auki
# Processing Record 16 of Set 3 | dingle
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | sergeyevka
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | yellowknife
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | mitsamiouli
# Processing Record 24 of Set 3 | goundi
# Processing Record 25 of Set 3 | darhan
# Processing Record 26 of Set 3 | kirovskiy
# Processing Record 27 of Set 3 | tuatapere
# Processing Record 28 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 3 | alugan
# Processing Record 30 of Set 3 | laje
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | tual
# Processing Record 33 of Set 3 | vanavara
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | zboriste
# Processing Record 36 of Set 3 | brae
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | benguela
# Processing Record 39 of Set 3 | maragheh
# Processing Record 40 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | ituporanga
# Processing Record 43 of Set 3 | half moon bay
# Processing Record 44 of Set 3 | tecoanapa
# Processing Record 45 of Set 3 | silver city
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | byron bay
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | marsa matruh
# Processing Record 50 of Set 3 | san andres
# Processing Record 1 of Set 4 | boali
# Processing Record 2 of Set 4 | lake city
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | srednekolymsk
# Processing Record 5 of Set 4 | zaragoza
# Processing Record 6 of Set 4 | muros
# Processing Record 7 of Set 4 | the pas
# Processing Record 8 of Set 4 | poya
# Processing Record 9 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 4 | sorland
# Processing Record 11 of Set 4 | mogadishu
# Processing Record 12 of Set 4 | imeni poliny osipenko
# Processing Record 13 of Set 4 | qui nhon
# Processing Record 14 of Set 4 | carnduff
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | salimpur
# Processing Record 17 of Set 4 | navahrudak
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | conroe
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 4 | sao joao da barra
# Processing Record 29 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 4 | camacha
# Processing Record 31 of Set 4 | saint-pierre
# Processing Record 32 of Set 4 | manokwari
# Processing Record 33 of Set 4 | pirgos
# Processing Record 34 of Set 4 | prachin buri
# Processing Record 35 of Set 4 | la ronge
# Processing Record 36 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 4 | mugur-aksy
# Processing Record 38 of Set 4 | sungurlu
# Processing Record 39 of Set 4 | isla mujeres
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | bilma
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | broken hill
# Processing Record 44 of Set 4 | smidovich
# Processing Record 45 of Set 4 | khatanga
# Processing Record 46 of Set 4 | souillac
# Processing Record 47 of Set 4 | eyl
# Processing Record 48 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 4 | aswan
# Processing Record 50 of Set 4 | coatzintla
# Processing Record 1 of Set 5 | taltal
# Processing Record 2 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | diu
# Processing Record 4 of Set 5 | acapulco
# Processing Record 5 of Set 5 | esperance
# Processing Record 6 of Set 5 | bathsheba
# Processing Record 7 of Set 5 | stephenville
# Processing Record 8 of Set 5 | durango
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 5 | roma
# Processing Record 15 of Set 5 | chernyshevskiy
# Processing Record 16 of Set 5 | dabat
# Processing Record 17 of Set 5 | san carlos
# Processing Record 18 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 5 | concordia
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | linxia
# Processing Record 23 of Set 5 | gejiu
# Processing Record 24 of Set 5 | richard toll
# City not found. Skipping...
# Processing Record 25 of Set 5 | krasnokholmskiy
# Processing Record 26 of Set 5 | pevek
# Processing Record 27 of Set 5 | biloela
# Processing Record 28 of Set 5 | verkhnetulomskiy
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | tshikapa
# Processing Record 33 of Set 5 | palm coast
# Processing Record 34 of Set 5 | fukue
# Processing Record 35 of Set 5 | anadyr
# Processing Record 36 of Set 5 | longonjo
# Processing Record 37 of Set 5 | huicungo
# Processing Record 38 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 5 | nikel
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | faro
# Processing Record 42 of Set 5 | kefamenanu
# Processing Record 43 of Set 5 | quesnel
# Processing Record 44 of Set 5 | severo-yeniseyskiy
# Processing Record 45 of Set 5 | acurenam
# Processing Record 46 of Set 5 | hofn
# Processing Record 47 of Set 5 | comodoro rivadavia
# Processing Record 48 of Set 5 | cap malheureux
# Processing Record 49 of Set 5 | tasiilaq
# Processing Record 50 of Set 5 | buraydah
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | moerai
# Processing Record 3 of Set 6 | oktyabrskiy
# Processing Record 4 of Set 6 | burica
# City not found. Skipping...
# Processing Record 5 of Set 6 | alofi
# Processing Record 6 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 6 | ahipara
# Processing Record 8 of Set 6 | santiago
# Processing Record 9 of Set 6 | ciudad bolivar
# Processing Record 10 of Set 6 | saint-leu
# Processing Record 11 of Set 6 | alta floresta
# Processing Record 12 of Set 6 | beroroha
# Processing Record 13 of Set 6 | dalby
# Processing Record 14 of Set 6 | copiapo
# Processing Record 15 of Set 6 | yazman
# Processing Record 16 of Set 6 | gimli
# Processing Record 17 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 6 | egvekinot
# Processing Record 19 of Set 6 | general roca
# Processing Record 20 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 6 | baragua
# Processing Record 22 of Set 6 | valer
# Processing Record 23 of Set 6 | kavieng
# Processing Record 24 of Set 6 | iqaluit
# Processing Record 25 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 6 | mattru
# Processing Record 27 of Set 6 | singaparna
# Processing Record 28 of Set 6 | krasnyy kholm
# Processing Record 29 of Set 6 | mandalgovi
# Processing Record 30 of Set 6 | balkanabat
# Processing Record 31 of Set 6 | fujin
# Processing Record 32 of Set 6 | port macquarie
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | mecca
# Processing Record 35 of Set 6 | sayyan
# Processing Record 36 of Set 6 | cukai
# Processing Record 37 of Set 6 | homer
# Processing Record 38 of Set 6 | urubicha
# Processing Record 39 of Set 6 | kachiry
# Processing Record 40 of Set 6 | guanica
# Processing Record 41 of Set 6 | praia da vitoria
# Processing Record 42 of Set 6 | moen
# Processing Record 43 of Set 6 | diffa
# Processing Record 44 of Set 6 | superior
# Processing Record 45 of Set 6 | zheleznodorozhnyy
# Processing Record 46 of Set 6 | jiuquan
# Processing Record 47 of Set 6 | kozan
# Processing Record 48 of Set 6 | asyut
# Processing Record 49 of Set 6 | kameshkovo
# Processing Record 50 of Set 6 | gabu
# Processing Record 1 of Set 7 | flin flon
# Processing Record 2 of Set 7 | padang
# Processing Record 3 of Set 7 | bonavista
# Processing Record 4 of Set 7 | along
# Processing Record 5 of Set 7 | huallanca
# Processing Record 6 of Set 7 | russell
# Processing Record 7 of Set 7 | rocha
# Processing Record 8 of Set 7 | zalantun
# Processing Record 9 of Set 7 | lamu
# Processing Record 10 of Set 7 | cayenne
# Processing Record 11 of Set 7 | talnakh
# Processing Record 12 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 13 of Set 7 | mannarakkat
# Processing Record 14 of Set 7 | zhangye
# Processing Record 15 of Set 7 | richards bay
# Processing Record 16 of Set 7 | uglekamensk
# Processing Record 17 of Set 7 | slatina
# Processing Record 18 of Set 7 | pudozh
# Processing Record 19 of Set 7 | lososina
# Processing Record 20 of Set 7 | upernavik
# Processing Record 21 of Set 7 | havelock
# Processing Record 22 of Set 7 | mahebourg
# Processing Record 23 of Set 7 | tromso
# Processing Record 24 of Set 7 | ajdabiya
# Processing Record 25 of Set 7 | harper
# Processing Record 26 of Set 7 | zaraza
# Processing Record 27 of Set 7 | hithadhoo
# Processing Record 28 of Set 7 | chicama
# Processing Record 29 of Set 7 | mezen
# Processing Record 30 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 7 | akureyri
# Processing Record 32 of Set 7 | manhattan
# Processing Record 33 of Set 7 | wala
# Processing Record 34 of Set 7 | clyde river
# Processing Record 35 of Set 7 | ponta delgada
# Processing Record 36 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 7 | sioux lookout
# Processing Record 38 of Set 7 | tofield
# Processing Record 39 of Set 7 | oranjemund
# Processing Record 40 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 7 | agadez
# Processing Record 42 of Set 7 | yamada
# Processing Record 43 of Set 7 | sjovegan
# Processing Record 44 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 7 | tabou
# Processing Record 46 of Set 7 | schweinfurt
# Processing Record 47 of Set 7 | dhidhdhoo
# Processing Record 48 of Set 7 | mana
# Processing Record 49 of Set 7 | igboho
# Processing Record 50 of Set 7 | plouzane
# Processing Record 1 of Set 8 | tautira
# Processing Record 2 of Set 8 | aberdeen
# Processing Record 3 of Set 8 | amasya
# Processing Record 4 of Set 8 | dalnegorsk
# Processing Record 5 of Set 8 | carutapera
# Processing Record 6 of Set 8 | zeya
# Processing Record 7 of Set 8 | newcastle
# Processing Record 8 of Set 8 | nabire
# Processing Record 9 of Set 8 | hanzhong
# Processing Record 10 of Set 8 | lavrentiya
# Processing Record 11 of Set 8 | ostersund
# Processing Record 12 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 8 | pilot butte
# Processing Record 14 of Set 8 | tilichiki
# Processing Record 15 of Set 8 | mucurapo
# Processing Record 16 of Set 8 | ivanteyevka
# Processing Record 17 of Set 8 | bonthe
# Processing Record 18 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 19 of Set 8 | roald
# Processing Record 20 of Set 8 | seoul
# Processing Record 21 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | arcachon
# Processing Record 24 of Set 8 | santa catalina
# Processing Record 25 of Set 8 | porto santo
# Processing Record 26 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 8 | ust-nera
# Processing Record 28 of Set 8 | naze
# Processing Record 29 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 8 | laguna
# Processing Record 31 of Set 8 | beaufort
# Processing Record 32 of Set 8 | sinnamary
# Processing Record 33 of Set 8 | katsuura
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | los algarrobos
# Processing Record 36 of Set 8 | vanimo
# Processing Record 37 of Set 8 | hualmay
# Processing Record 38 of Set 8 | mansa
# Processing Record 39 of Set 8 | tinogboc
# Processing Record 40 of Set 8 | raipur
# Processing Record 41 of Set 8 | kununurra
# Processing Record 42 of Set 8 | kuala terengganu
# Processing Record 43 of Set 8 | saldanha
# Processing Record 44 of Set 8 | wahpeton
# Processing Record 45 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 8 | riohacha
# Processing Record 48 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 49 of Set 8 | haines junction
# Processing Record 50 of Set 8 | shubarkuduk
# Processing Record 1 of Set 9 | ferme-neuve
# Processing Record 2 of Set 9 | tommot
# Processing Record 3 of Set 9 | luang prabang
# Processing Record 4 of Set 9 | havoysund
# Processing Record 5 of Set 9 | wukari
# Processing Record 6 of Set 9 | kysyl-syr
# Processing Record 7 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 9 | buenavista
# Processing Record 9 of Set 9 | kieta
# Processing Record 10 of Set 9 | jinka
# Processing Record 11 of Set 9 | jibuti
# Processing Record 12 of Set 9 | sayla
# Processing Record 13 of Set 9 | thinadhoo
# Processing Record 14 of Set 9 | mayahi
# Processing Record 15 of Set 9 | thompson
# Processing Record 16 of Set 9 | nisia floresta
# Processing Record 17 of Set 9 | kavaratti
# Processing Record 18 of Set 9 | pascagoula
# Processing Record 19 of Set 9 | taman
# Processing Record 20 of Set 9 | truckee
# Processing Record 21 of Set 9 | zlocieniec
# Processing Record 22 of Set 9 | coihaique
# Processing Record 23 of Set 9 | vavatenina
# Processing Record 24 of Set 9 | tolaga bay
# Processing Record 25 of Set 9 | merrill
# Processing Record 26 of Set 9 | khasan
# Processing Record 27 of Set 9 | puerto narino
# Processing Record 28 of Set 9 | reguengos de monsaraz
# Processing Record 29 of Set 9 | najran
# Processing Record 30 of Set 9 | guaratuba
# Processing Record 31 of Set 9 | victoria
# Processing Record 32 of Set 9 | pedernales
# Processing Record 33 of Set 9 | zhigalovo
# Processing Record 34 of Set 9 | chokwe
# Processing Record 35 of Set 9 | datong
# Processing Record 36 of Set 9 | tigil
# Processing Record 37 of Set 9 | pisco
# Processing Record 38 of Set 9 | esfarayen
# Processing Record 39 of Set 9 | severnyy
# Processing Record 40 of Set 9 | pacific grove
# Processing Record 41 of Set 9 | hervey bay
# Processing Record 42 of Set 9 | seybaplaya
# Processing Record 43 of Set 9 | sao jose da coroa grande
# Processing Record 44 of Set 9 | vao
# Processing Record 45 of Set 9 | san juan
# Processing Record 46 of Set 9 | guerrero negro
# Processing Record 47 of Set 9 | alice springs
# Processing Record 48 of Set 9 | ixtapa
# Processing Record 49 of Set 9 | inhambane
# Processing Record 50 of Set 9 | beausejour
# Processing Record 1 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 10 | paracuru
# Processing Record 3 of Set 10 | gumusyaka
# City not found. Skipping...
# Processing Record 4 of Set 10 | eureka
# Processing Record 5 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 10 | esmeraldas
# Processing Record 7 of Set 10 | kodinsk
# Processing Record 8 of Set 10 | wanning
# Processing Record 9 of Set 10 | kyzyl-suu
# Processing Record 10 of Set 10 | yaan
# Processing Record 11 of Set 10 | bria
# Processing Record 12 of Set 10 | codrington
# Processing Record 13 of Set 10 | kralendijk
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | kahului
# Processing Record 16 of Set 10 | sotouboua
# Processing Record 17 of Set 10 | nouadhibou
# Processing Record 18 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 10 | calahorra
# Processing Record 20 of Set 10 | waipawa
# Processing Record 21 of Set 10 | vostok
# Processing Record 22 of Set 10 | vila franca do campo
# Processing Record 23 of Set 10 | marawi
# Processing Record 24 of Set 10 | malinyi
# Processing Record 25 of Set 10 | maniitsoq
# Processing Record 26 of Set 10 | altamira
# Processing Record 27 of Set 10 | saint-georges
# Processing Record 28 of Set 10 | nambucca heads
# Processing Record 29 of Set 10 | grand gaube
# Processing Record 30 of Set 10 | kenai
# Processing Record 31 of Set 10 | hami
# Processing Record 32 of Set 10 | port keats
# Processing Record 33 of Set 10 | burnie
# Processing Record 34 of Set 10 | necochea
# Processing Record 35 of Set 10 | vestmannaeyjar
# Processing Record 36 of Set 10 | gamboma
# Processing Record 37 of Set 10 | chiang khong
# Processing Record 38 of Set 10 | igarka
# Processing Record 39 of Set 10 | leningradskiy
# Processing Record 40 of Set 10 | shimoda
# Processing Record 41 of Set 10 | mbandaka
# Processing Record 42 of Set 10 | serpa
# Processing Record 43 of Set 10 | labuhan
# Processing Record 44 of Set 10 | peniche
# Processing Record 45 of Set 10 | atar
# Processing Record 46 of Set 10 | sarangani
# Processing Record 47 of Set 10 | goba
# Processing Record 48 of Set 10 | togur
# Processing Record 49 of Set 10 | luganville
# Processing Record 50 of Set 10 | sobolevo
# Processing Record 1 of Set 11 | ewa beach
# Processing Record 2 of Set 11 | portland
# Processing Record 3 of Set 11 | lebowakgomo
# Processing Record 4 of Set 11 | biltine
# Processing Record 5 of Set 11 | panguipulli
# Processing Record 6 of Set 11 | kouroussa
# Processing Record 7 of Set 11 | port-cartier
# Processing Record 8 of Set 11 | viedma
# Processing Record 9 of Set 11 | merauke
# Processing Record 10 of Set 11 | balkhash
# Processing Record 11 of Set 11 | teguise
# Processing Record 12 of Set 11 | turukhansk
# Processing Record 13 of Set 11 | seymchan
# Processing Record 14 of Set 11 | hastings
# Processing Record 15 of Set 11 | svetlaya
# Processing Record 16 of Set 11 | phumi samraong
# City not found. Skipping...
# Processing Record 17 of Set 11 | alekseyevka
# Processing Record 18 of Set 11 | keita
# Processing Record 19 of Set 11 | aksu
# Processing Record 20 of Set 11 | freeport
# Processing Record 21 of Set 11 | nobeoka
# Processing Record 22 of Set 11 | manjeshwar
# Processing Record 23 of Set 11 | svetlogorsk
# Processing Record 24 of Set 11 | shetpe
# Processing Record 25 of Set 11 | andilamena
# Processing Record 26 of Set 11 | fernie
# Processing Record 27 of Set 11 | husavik
# Processing Record 28 of Set 11 | samana
# Processing Record 29 of Set 11 | porteirinha
# Processing Record 30 of Set 11 | brenham
# Processing Record 31 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 11 | ottawa
# Processing Record 33 of Set 11 | mayo
# Processing Record 34 of Set 11 | pareora
# Processing Record 35 of Set 11 | san borja
# Processing Record 36 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 11 | liuli
# Processing Record 38 of Set 11 | rudnaya pristan
# Processing Record 39 of Set 11 | porosozero
# Processing Record 40 of Set 11 | shellbrook
# Processing Record 41 of Set 11 | diego de almagro
# Processing Record 42 of Set 11 | sumkino
# Processing Record 43 of Set 11 | roros
# Processing Record 44 of Set 11 | ancud
# Processing Record 45 of Set 11 | shitanjing
# Processing Record 46 of Set 11 | quatre cocos
# Processing Record 47 of Set 11 | ozernovskiy
# Processing Record 48 of Set 11 | kaniama
# Processing Record 49 of Set 11 | college
# Processing Record 50 of Set 11 | charters towers
# Processing Record 1 of Set 12 | play cu
# City not found. Skipping...
# Processing Record 2 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 12 | millinocket
# Processing Record 4 of Set 12 | sao miguel do araguaia
# Processing Record 5 of Set 12 | bambanglipuro
# Processing Record 6 of Set 12 | enshi
# Processing Record 7 of Set 12 | kidal
# Processing Record 8 of Set 12 | dafeng
# Processing Record 9 of Set 12 | areosa
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | porto murtinho
# Processing Record 12 of Set 12 | bogorodskoye
# Processing Record 13 of Set 12 | havre-saint-pierre
# Processing Record 14 of Set 12 | kumano
# Processing Record 15 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 16 of Set 12 | belmonte
# Processing Record 17 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 18 of Set 12 | makabe
# Processing Record 19 of Set 12 | vila velha
# Processing Record 20 of Set 12 | jardim
# Processing Record 21 of Set 12 | konevo
# Processing Record 22 of Set 12 | madang
# Processing Record 23 of Set 12 | khorinsk
# Processing Record 24 of Set 12 | channel-port aux basques
# Processing Record 25 of Set 12 | corsicana
# Processing Record 26 of Set 12 | sur
# Processing Record 27 of Set 12 | tazovskiy
# Processing Record 28 of Set 12 | tessalit
# Processing Record 29 of Set 12 | kamenka
# Processing Record 30 of Set 12 | uthal
# Processing Record 31 of Set 12 | maltahohe
# Processing Record 32 of Set 12 | xuddur
# Processing Record 33 of Set 12 | rafai
# Processing Record 34 of Set 12 | sechura
# Processing Record 35 of Set 12 | srisailam
# Processing Record 36 of Set 12 | dunedin
# Processing Record 37 of Set 12 | puerto palomas
# Processing Record 38 of Set 12 | saryozek
# Processing Record 39 of Set 12 | capao bonito
# Processing Record 40 of Set 12 | tobermory
# Processing Record 41 of Set 12 | umba
# Processing Record 42 of Set 12 | strezhevoy
# Processing Record 43 of Set 12 | edea
# Processing Record 44 of Set 12 | fuling
# Processing Record 45 of Set 12 | spring hill
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          541
# Lat           541
# Lng           541
# Max Temp      541
# Humidity      541
# Cloudiness    541
# Wind Speed    541
# Country       541
# Date          541
# dtype: int64

# %%
# Converting date to datetime format
city_data_df["Date"]  = pd.to_datetime(city_data_df["Date"], unit='s').dt.strftime('%Y-%m-%d')
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Ballymena  54.8636   -6.2763    282.05        92         100        3.97
# 1      Marzuq  14.4000   46.4667    296.56        65          10        2.63
# 2  Nikolskoye  59.7035   30.7861    278.66        95          66        3.46
# 3        Sola -13.8833  167.5500    300.10        74          97        3.01
# 4      Kodiak  57.7900 -152.4072    271.88        43           0        6.69
#
#   Country        Date
# 0      GB  2023-03-23
# 1      YE  2023-03-23
# 2      RU  2023-03-23
# 3      VU  2023-03-23
# 4      US  2023-03-23

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Ballymena  54.8636   -6.2763    282.05        92         100
# 1            Marzuq  14.4000   46.4667    296.56        65          10
# 2        Nikolskoye  59.7035   30.7861    278.66        95          66
# 3              Sola -13.8833  167.5500    300.10        74          97
# 4            Kodiak  57.7900 -152.4072    271.88        43           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.97      GB  2023-03-23
# 1              2.63      YE  2023-03-23
# 2              3.46      RU  2023-03-23
# 3              3.01      VU  2023-03-23
# 4              6.69      US  2023-03-23

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"],edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2023-03-23)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"],edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity % (2023-03-23)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"],edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%) (2023-03-23)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"],edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-03-23)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def lin_reg(x,y):
    print(f"The r-value is: {(np.corrcoef(x, y)[0,1])}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x, regress_values, "r-")
    print(line_eq)
    return line_eq

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Ballymena  54.8636   -6.2763    282.05        92         100
# 1            Marzuq  14.4000   46.4667    296.56        65          10
# 2        Nikolskoye  59.7035   30.7861    278.66        95          66
# 4            Kodiak  57.7900 -152.4072    271.88        43           0
# 6            Barrow  71.2906 -156.7887    258.16        85         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.97      GB  2023-03-23
# 1              2.63      YE  2023-03-23
# 2              3.46      RU  2023-03-23
# 4              6.69      US  2023-03-23
# 6              5.14      US  2023-03-23

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                Sola -13.8833  167.5500    300.10        74          97
# 5        Punta Arenas -53.1500  -70.9167    283.21        53          75
# 10            Rikitea -23.1203 -134.9692    298.83        66          98
# 15           Hermanus -34.4187   19.2345    293.60        92         100
# 20            Mataura -46.1927  168.8643    278.52        99          60
#
#          Wind Speed Country        Date
# City_ID
# 3              3.01      VU  2023-03-23
# 5              7.20      CL  2023-03-23
# 10             5.58      PF  2023-03-23
# 15             3.07      ZA  2023-03-23
# 20             0.95      NZ  2023-03-23

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# calling Linear regression function

equ_1 = lin_reg(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Show plot
plt.show()
# Out:
# The r-value is: -0.8679041129985148
# y = -0.68x +309.35

# %%
# Linear regression on Southern Hemisphere
equ_2 = lin_reg(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Show plot
plt.show()
# Out:
# The r-value is: 0.6596954528352562
# y = 0.3x +302.63

# %% [markdown]
# Max Temperature and Latitude have a strong negative correlation in the Northern Hemisphere confirmed by the scatter plot regression line and an r value of -0.87. The Southern Hemisphere shows a moderate positive correlation between these two factors with an r value of 0.66.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equ_1 = lin_reg(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Show plot
plt.show()
# Out:
# The r-value is: 0.3536620404541696
# y = 0.38x +57.59

# %%
# Southern Hemisphere
equ_1 = lin_reg(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Show plot
plt.show()
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
